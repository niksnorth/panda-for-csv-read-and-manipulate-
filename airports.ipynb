# %%
import pandas as pd

airports = pd.read_csv('airports.csv')
type(airports)
# Out:
# pandas.core.frame.DataFrame

# %%
airports[airports.ident == 'KLAX']
# Out:
#          id ident           type                               name  \
# 27743  3632  KLAX  large_airport  Los Angeles International Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 27743     33.942501    -118.407997         125.0       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 27743      US-CA  Los Angeles               yes     KLAX       LAX        LAX
#
#                      home_link  \
# 27743  http://www.iflylax.com/
#
#                                           wikipedia_link keywords
# 27743  http://en.wikipedia.org/wiki/Los_Angeles_Inter...      NaN

# %%
airports.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'seaplane_base')]
# Out:
#            id ident           type                                      name  \
# 977      7436   0O0  seaplane_base          San Luis Reservoir Seaplane Base
# 2492     8877  22CA  seaplane_base            Commodore Center Seaplane Base
# 6236    12298  5CA9  seaplane_base       Konocti  - Clear Lake Seaplane Base
# 12898   16514   C39  seaplane_base                 Folsom Lake Seaplane Base
# 15216   16830  CN20  seaplane_base             Ferndale Resort Seaplane Base
# 17585   17157   E20  seaplane_base              Lake Berryessa Seaplane Base
# 22728   17613   H77  seaplane_base           Bridge Bay Resort Seaplane Base
# 30482   21444   L11  seaplane_base                Pebbly Beach Seaplane Base
# 36981   23479   O06  seaplane_base  Lake Oroville Landing Area Seaplane Base
# 40630   24384   S74  seaplane_base                   Lost Isle Seaplane Base
# 48057  300312   TWH  seaplane_base           Two Harbors Amphibious Terminal
#
# ...

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'large_airport')][['ident', 'name', 'municipality']]
# Out:
#       ident                                             name   municipality
# 26113  KBAB                             Beale Air Force Base     Marysville
# 26953  KEDW                           Edwards Air Force Base        Edwards
# 27743  KLAX                Los Angeles International Airport    Los Angeles
# 28270  KOAK       Metropolitan Oakland International Airport        Oakland
# 28326  KONT                    Ontario International Airport        Ontario
# 29848  KSAN                  San Diego International Airport      San Diego
# 29888  KSFO              San Francisco International Airport  San Francisco
# 29909  KSJC  Norman Y. Mineta San Jose International Airport       San Jose
# 29931  KSMF                 Sacramento International Airport     Sacramento
# 29937  KSNA         John Wayne Airport-Orange County Airport      Santa Ana
# 29986  KSUU                            Travis Air Force Base      Fairfield
# ...

# %%
airports[airports.iso_region == 'US-PA'].sort_values('type', ascending=False)
# Out:
#            id    ident           type  \
# 51485   25593      W73  small_airport
# 8196    14115      7G4  small_airport
# 38893   24112     PN02  small_airport
# 38895   24114     PN04  small_airport
# 38897   24116     PN06  small_airport
# 8447    14359     7PN0  small_airport
# 38899   24118     PN08  small_airport
# 38901   24120     PN10  small_airport
# 38902   24121     PN11  small_airport
# 8442    14354     7PA5  small_airport
# 8441    14353     7PA4  small_airport
# 8440    14352     7PA3  small_airport
# 38903   24122     PN12  small_airport
# 8438    14350     7PA1  small_airport
# 38904   24123     PN13  small_airport
# 8346    14262      7N8  small_airport
# 38905   24124     PN14  small_airport
# 38891   24110     PN00  small_airport
# 8091    14028     79PA  small_airport
# 8081    14018      79N  small_airport
# 38906   24125     PN15  small_airport
# 38907   24126     PN16  small_airport
# 8003    13949     77PN  small_airport
# ...

# %%
len(airports)
# Out:
# 54962

# %%
airports[airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident      type  \
# 0        6523      00A  heliport
# 9      322658     00CN  heliport
# 12       6532     00FD  heliport
# 15       6535     00GE  heliport
# 16       6536     00HI  heliport
# 19       6538     00II  heliport
# 21       6540     00IN  heliport
# 25      45437     00LA  heliport
# 26       6544     00LL  heliport
# 29       6547     00MI  heliport
# 35       6553     00NJ  heliport
# 39       6556     00OI  heliport
# 41       6557     00OR  heliport
# 42       6558     00PA  heliport
# 47       6562     00TA  heliport
# 48       6563     00TE  heliport
# 60     322300     00WY  heliport
# 63       6577     01AK  heliport
# 65       6579     01AR  heliport
# 66       6580     01AZ  heliport
# 68       6582     01CA  heliport
# 70       6584     01CN  heliport
# 71       6585     01CO  heliport
# 72       6586     01CT  heliport
# 74       6588     01FD  heliport
# 76       6590     01GA  heliport
# 81       6594     01IL  heliport
# ...

# %%
airports[~airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident            type  \
# 1      323361     00AA   small_airport
# 2        6524     00AK   small_airport
# 3        6525     00AL   small_airport
# 4        6526     00AR          closed
# 5      322127     00AS   small_airport
# 6        6527     00AZ   small_airport
# 7        6528     00CA   small_airport
# 8      324424     00CL   small_airport
# 10       6529     00CO          closed
# 11       6531     00FA   small_airport
# 13       6533     00FL   small_airport
# 14       6534     00GA   small_airport
# 17       6537     00ID   small_airport
# 18     322581     00IG   small_airport
# 20       6539     00IL   small_airport
# 22       6541     00IS   small_airport
# 23       6542     00KS   small_airport
# 24       6543     00KY   small_airport
# 27       6545     00LS   small_airport
# 28       6546     00MD   small_airport
# 30       6548     00MN   small_airport
# 31       6549     00MO   small_airport
# 32       6550     00MT          closed
# ...

# %%
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           heliport            2
# AE           closed              4
#              heliport           21
#              large_airport       4
#              medium_airport      8
#              seaplane_base       3
#              small_airport      16
# AF           closed              2
#              heliport            3
#              medium_airport      8
#              small_airport      51
# AG           medium_airport      1
#              small_airport       2
# AI           medium_airport      1
# AL           closed              6
#              heliport            1
#              large_airport       1
#              medium_airport      3
#              small_airport       1
# AM           closed              4
#              large_airport       1
#              medium_airport      3
#              small_airport       5
# AO           closed             10
#              large_airport       1
#              medium_airport     20
# ...

# %%
airports[(airports.type =='heliport') & (airports.iso_country == 'AE')].sort_values(['type'])
# Out:
#            id    ident      type  \
# 10366   44426  AE-0002  heliport
# 10386  319187  AE-0022  heliport
# 10385  319185  AE-0021  heliport
# 10384  319184  AE-0020  heliport
# 10383  319183  AE-0019  heliport
# 10382  319181  AE-0018  heliport
# 10381  319180  AE-0017  heliport
# 10380  319179  AE-0016  heliport
# 10379  319178  AE-0015  heliport
# 10387  319188  AE-0023  heliport
# 10378  319177  AE-0014  heliport
# 10376  319175  AE-0012  heliport
# 10375  319174  AE-0011  heliport
# 10374  319172  AE-0010  heliport
# 10373  315508  AE-0009  heliport
# 10372  313548  AE-0008  heliport
# 10371  313547  AE-0007  heliport
# 10369  307258  AE-0005  heliport
# 10368  307257  AE-0004  heliport
# 10377  319176  AE-0013  heliport
# 10389  319193  AE-0025  heliport
#
#                                                     name  latitude_deg  \
# 10366                        Burj al Arab Resort Helipad     25.141327
# 10386                          Al Mushrif Palace Helipad     24.452066
# ...

# %%
airports.groupby(['iso_country', 'type']).size().to_frame('size').reset_index().sort_values(['iso_country', 'size'], ascending=[True, True])
# Out:
#     iso_country            type  size
# 0            AD        heliport     2
# 5            AE   seaplane_base     3
# 1            AE          closed     4
# 3            AE   large_airport     4
# 4            AE  medium_airport     8
# 6            AE   small_airport    16
# 2            AE        heliport    21
# 7            AF          closed     2
# 8            AF        heliport     3
# 9            AF  medium_airport     8
# 10           AF   small_airport    51
# 11           AG  medium_airport     1
# 12           AG   small_airport     2
# 13           AI  medium_airport     1
# 15           AL        heliport     1
# 16           AL   large_airport     1
# 18           AL   small_airport     1
# 17           AL  medium_airport     3
# 14           AL          closed     6
# 20           AM   large_airport     1
# 21           AM  medium_airport     3
# 19           AM          closed     4
# 22           AM   small_airport     5
# 24           AO   large_airport     1
# ...

# %%
airports[airports.iso_country == 'US'].groupby('type').filter(lambda g: len(g) > 1000).groupby('type').size().sort_values(ascending=True)
# Out:
# type
# closed            1291
# heliport          6258
# small_airport    13729
# dtype: int64

# %%
by_country=airports.groupby('iso_country').size().groupby('iso_country').size().sort_values(ascending=True)

# %%
by_country2=airports.groupby(['iso_country', 'type']).size().to_frame('airport_count').reset_index().sort_values(['iso_country', 'airport_count'], ascending=[True, True])

# %%
by_country2.head()
# Out:
#   iso_country            type  airport_count
# 0          AD        heliport              2
# 5          AE   seaplane_base              3
# 1          AE          closed              4
# 3          AE   large_airport              4
# 4          AE  medium_airport              8

# %%
by_country2.nlargest(10, columns='airport_count')
# Out:
#     iso_country           type  airport_count
# 790          US  small_airport          13729
# 786          US       heliport           6258
# 104          BR  small_airport           3076
# 49           AU  small_airport           1537
# 785          US         closed           1291
# 425          KR       heliport           1259
# 132          CA  small_airport            995
# 101          BR       heliport            972
# 536          MX  small_airport            813
# 199          DE  small_airport            748

# %%
by_country2.nlargest(25, columns='airport_count')
# Out:
#     iso_country            type  airport_count
# 790          US   small_airport          13729
# 786          US        heliport           6258
# 104          BR   small_airport           3076
# 49           AU   small_airport           1537
# 785          US          closed           1291
# 425          KR        heliport           1259
# 132          CA   small_airport            995
# 101          BR        heliport            972
# 536          MX   small_airport            813
# 199          DE   small_airport            748
# 788          US  medium_airport            692
# 127          CA          closed            652
# 35           AR   small_airport            621
# 169          CO   small_airport            593
# 277          GB   small_airport            569
# 789          US   seaplane_base            565
# 386          IT   small_airport            545
# 599          PG   small_airport            505
# 654          RU   small_airport            491
# ...

# %%
pd.concat([airports[airports.ident == 'KLAX'][['name', 'municipality']], airports[airports.ident == 'KLGB'][['name', 'municipality']]])
# Out:
#                                        name municipality
# 27743     Los Angeles International Airport  Los Angeles
# 27768  Long Beach /Daugherty Field/ Airport   Long Beach

# %%
airports.agg({'id': ['min', 'max', 'mean', 'median']}).T
# Out:
#     min       max          mean   median
# id  2.0  330251.0  82939.201976  27713.5

# %%
id_stats=airports.id

# %%
id_stats.head()
# Out:
# 0      6523
# 1    323361
# 2      6524
# 3      6525
# 4      6526
# Name: id, dtype: int64

# %%
len(id_stats)
# Out:
# 54962

# %%
type(airports)
# Out:
# pandas.core.frame.DataFrame

# %%
type(id_stats)
# Out:
# pandas.core.series.Series

# %%
df1 = pd.DataFrame({'id': [1, 2], 'name': ['Harry Potter', 'Ron Weasley']})

# %%
df2 = pd.DataFrame({'id': [3], 'name': ['Hermione Granger']})

# %%
pd.concat([df1, df2]).reset_index(drop=True)
# Out:
#    id              name
# 0   1      Harry Potter
# 1   2       Ron Weasley
# 2   3  Hermione Granger

# %%
# %matplotlib inline
top_10 = by_country2.head(10).sort_values('airport_count', ascending=False)
top_10.plot(
    x='iso_country', 
    y='airport_count',
    kind='barh',
    figsize=(10, 7),
title='Top 10 countries with most airports')

# %%
dff = pd.DataFrame(data = {100, liste_hello})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-8183bbff3a81> in <module>
# ----> 1 dff = pd.DataFrame(data = {100, liste_hello})
#
# NameError: name 'liste_hello' is not defined

# %%
liste_hello = ['niks','North']

# %%
dff = pd.DataFrame({100, 'Nik', 'singh'},columns='StudentID FirstName LastName'.split())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-aaeaa7a28a90> in <module>
# ----> 1 dff = pd.DataFrame({100, 'Nik', 'singh'},columns='StudentID FirstName LastName'.split())
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# --> 422                 raise ValueError('DataFrame constructor not properly called!')
#     423
#     424         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!
